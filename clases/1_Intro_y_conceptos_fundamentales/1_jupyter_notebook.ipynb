# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/2025-segundo-semestre-ia-economia/blob/main/clases/1_Intro_y_conceptos_fundamentales/1_jupyter_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # **Conociendo Jupyter Notebook**

# %% [markdown]
# Se utiliza Python 3.13.5

# %% [markdown]
# ## Importar librerías

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Ajustar formato visualización

# %%
# Aumentar número de columnas que se pueden ver
# Que muestre 500 columnas máximo
pd.options.display.max_columns = 500
# Que muestre todas las columnas
pd.options.display.max_columns = None

# %%
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Cargar base de datos

# %%
df = pd.read_csv('Base_municipios.txt', sep="|", decimal=',', encoding ='utf-8', converters={'Cod. Municipio':str})
df.head()
# Out:
#   Cod. Municipio Departamento   Municipio  Población municipio Subregión PDET  \
# 0          05001    Antioquia    Medellín              2572350            NaN
# 1          05002    Antioquia   Abejorral                21109            NaN
# 2          05004    Antioquia    Abriaquí                 2804            NaN
# 3          05021    Antioquia  Alejandría                 4874            NaN
# 4          05030    Antioquia       Amagá                31851            NaN
#
#    ZOMAC  Valor agregado municipio  % Act. primarias municipio  \
# 0      0                 66,432.28                        0.18
# 1      1                    314.20                       45.43
# 2      1                     38.48                       37.04
# 3      1                     67.95                       18.02
# 4      0                    635.93                        6.84
#
#    % Act. secundarias municipio  % Act. terciarias municipio  \
# 0                         20.06                        79.76
# 1                          6.37                        48.19
# 2                          6.45                        56.51
# 3                          6.89                        75.08
# 4                         46.20                        46.96
#
#    % pobl. con educación media municipio  \
# 0                                  26.54
# 1                                  12.80
# 2                                  21.40
# 3                                  14.64
# 4                                  22.83
#
#    % pobl. con edu. técnica/tecnología municipio  \
# 0                                          10.34
# 1                                           2.46
# 2                                           4.96
# 3                                           5.57
# 4                                           5.97
#
#    % pobl. con pregrado municipio  % pobl. con posgrado municipio  \
# 0                           11.83                            3.47
# 1                            1.73                            0.85
# 2                            2.69                            1.07
# 3                            2.92                            0.73
# 4                            2.95                            0.70
#
#    % pobreza municipio  % informalidad municipio  % mujeres municipio  \
# 0                12.80                     71.00                52.91
# 1                40.60                     87.50                47.79
# 2                34.80                     87.60                45.79
# 3                31.90                     87.10                50.39
# 4                22.90                     69.50                50.92
#
#    % jóvenes municipio  % pobl. con discapacidad municipio  \
# 0                24.48                                6.27
# 1                20.51                               16.05
# 2                22.04                               16.72
# 3                20.11                                8.10
# 4                23.26                                9.02
#
#    % grupos étnicos municipio  % pobl. campesina municipio  \
# 0                        2.59                         1.90
# 1                        0.36                          NaN
# 2                        2.04                          NaN
# 3                        0.31                          NaN
# 4                        0.52                          NaN
#
#    % pobl. LGBT municipio
# 0                    1.74
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN

# %% [markdown]
# ## Revisar contenido base de datos

# %%
# Ver el nombre de todas las columnas
df.columns
# Out:
# Index(['Cod. Municipio', 'Departamento', 'Municipio', 'Población municipio',
#        'Subregión PDET', 'ZOMAC', 'Valor agregado municipio',
#        '% Act. primarias municipio', '% Act. secundarias municipio',
#        '% Act. terciarias municipio', '% pobl. con educación media municipio',
#        '% pobl. con edu. técnica/tecnología municipio',
#        '% pobl. con pregrado municipio', '% pobl. con posgrado municipio',
#        '% pobreza municipio', '% informalidad municipio',
#        '% mujeres municipio', '% jóvenes municipio',
#        '% pobl. con discapacidad municipio', '% grupos étnicos municipio',
#        '% pobl. campesina municipio', '% pobl. LGBT municipio'],
#       dtype='object')

# %%
# Ver número de filas y columnas
df.shape
# Out:
# (1122, 22)

# %%
# Ver la cantidad de filas del df
len(df)
# Out:
# 1122

# %%
# Ver los tipos de datos de cada columna
df.dtypes
# Out:
# Cod. Municipio                                    object
# Departamento                                      object
# Municipio                                         object
# Población municipio                                int64
# Subregión PDET                                    object
# ZOMAC                                              int64
# Valor agregado municipio                         float64
# % Act. primarias municipio                       float64
# % Act. secundarias municipio                     float64
# % Act. terciarias municipio                      float64
# % pobl. con educación media municipio            float64
# % pobl. con edu. técnica/tecnología municipio    float64
# % pobl. con pregrado municipio                   float64
# % pobl. con posgrado municipio                   float64
# % pobreza municipio                              float64
# % informalidad municipio                         float64
# % mujeres municipio                              float64
# % jóvenes municipio                              float64
# % pobl. con discapacidad municipio               float64
# % grupos étnicos municipio                       float64
# % pobl. campesina municipio                      float64
# % pobl. LGBT municipio                           float64
# dtype: object

# %%
# Ver la cantidad de filas y columnas, el nombre todas las columnas, el tipo de datos y si tiene nulos
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1122 entries, 0 to 1121
# Data columns (total 22 columns):
#  #   Column                                         Non-Null Count  Dtype
# ---  ------                                         --------------  -----
#  0   Cod. Municipio                                 1122 non-null   object
#  1   Departamento                                   1122 non-null   object
#  2   Municipio                                      1122 non-null   object
#  3   Población municipio                            1122 non-null   int64
#  4   Subregión PDET                                 170 non-null    object
#  5   ZOMAC                                          1122 non-null   int64
#  6   Valor agregado municipio                       1121 non-null   float64
#  7   % Act. primarias municipio                     1121 non-null   float64
#  8   % Act. secundarias municipio                   1121 non-null   float64
#  9   % Act. terciarias municipio                    1121 non-null   float64
#  10  % pobl. con educación media municipio          1122 non-null   float64
#  11  % pobl. con edu. técnica/tecnología municipio  1122 non-null   float64
#  12  % pobl. con pregrado municipio                 1122 non-null   float64
#  13  % pobl. con posgrado municipio                 1122 non-null   float64
#  14  % pobreza municipio                            1122 non-null   float64
#  15  % informalidad municipio                       1122 non-null   float64
#  16  % mujeres municipio                            1121 non-null   float64
#  17  % jóvenes municipio                            1121 non-null   float64
#  18  % pobl. con discapacidad municipio             1122 non-null   float64
#  19  % grupos étnicos municipio                     1122 non-null   float64
#  20  % pobl. campesina municipio                    24 non-null     float64
#  21  % pobl. LGBT municipio                         24 non-null     float64
# dtypes: float64(16), int64(2), object(4)
# memory usage: 193.0+ KB
