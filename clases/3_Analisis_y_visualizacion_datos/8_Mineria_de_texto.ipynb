# %% [markdown]
# <a href="https://colab.research.google.com/github/LinaMariaCastro/curso-ia-para-economia/blob/main/clases/3_Analisis_y_visualizacion_datos/8_Mineria_de_texto.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Inteligencia Artificial con Aplicaciones en Economía I**
#
# - 👩‍🏫 **Profesora:** [Lina María Castro](https://www.linkedin.com/in/lina-maria-castro)
# - 📧 **Email:** [lmcastroco@gmail.com](mailto:lmcastroco@gmail.com)
# - 🎓 **Universidad:** Universidad Externado de Colombia - Facultad de Economía

# %% [markdown]
# # 📄 **Minería de texto y análisis de sentimientos**

# %% [markdown]
# **Objetivos de Aprendizaje**
#
# Al finalizar este notebook, serás capaz de:
#
# 1.  **Comprender la importancia del texto como fuente de datos**.
# 2.  **Realizar el preprocesamiento de un documento de texto**: limpieza, normalización, tokenización y eliminación de palabras muy comunes que no aportan mucho significado (*stop words*).
# 3.  **Aplicar técnicas de análisis de frecuencia** para identificar los términos más relevantes en un texto.
# 4.  **Visualizar los resultados** de un análisis de texto mediante nubes de palabras para una interpretación rápida e intuitiva.
# 5.  **Realizar análisis de sentimientos** sobre comentarios de empresas en internet.

# %% [markdown]
# ## Importar librerías
#
# Necesitaremos algunas librerías clave para el Procesamiento de Lenguaje Natural (NLP) como `nltk` y `wordcloud`.

# %%
# Instalamos las librerías necesarias, si no las hemos instalado previamente
# %pip install nltk wordcloud scikit-learn
# %pip install trasnformers
# Out:
# Requirement already satisfied: nltk in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (3.9.1)
# Requirement already satisfied: wordcloud in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (1.9.4)
# Requirement already satisfied: scikit-learn in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (1.7.1)
# Requirement already satisfied: click in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from nltk) (8.3.0)
# Requirement already satisfied: joblib in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from nltk) (1.5.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from nltk) (2025.9.18)
# Requirement already satisfied: tqdm in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from nltk) (4.67.1)
# Requirement already satisfied: numpy>=1.6.1 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (2.3.2)
# Requirement already satisfied: pillow in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from wordcloud) (3.10.5)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (1.16.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: colorama in c:\users\ferney reina\appdata\roaming\python\python313\site-packages (from click->nltk) (0.4.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ferney reina\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from matplotlib->wordcloud) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ferney reina\appdata\roaming\python\python313\site-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ferney reina\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not find a version that satisfies the requirement trasnformers (from versions: none)
# ERROR: No matching distribution found for trasnformers

# %%
import os
import nltk
import re
import pandas as pd
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# Descargamos componentes necesarios de NLTK (solo se ejecuta la primera vez)
nltk.download('punkt_tab')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt_tab to C:\Users\Ferney
# [nltk_data]     Reina\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt_tab.zip.
# [nltk_data] Downloading package stopwords to C:\Users\Ferney
# [nltk_data]     Reina\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\stopwords.zip.
# True

# %% [markdown]
# ## Mejorar visualización de los dataframes

# %%
# Que muestre todas las columnas
pd.options.display.max_columns = None
# En los dataframes, mostrar los float con dos decimales
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## El Corpus: Un Comunicado del Banco de la República
#
# Usaremos como *corpus* (nuestro conjunto de documentos de texto) un comunicado de prensa real del Banco de la República de Colombia publicado el 5 de agosto: "Minutas BanRep: La Junta Directiva del Banco de la República decidió por mayoría mantener inalterada la tasa de interés de política monetaria en 9,25%".
#
# Este tipo de documento es ideal porque su lenguaje tiene un impacto directo en las expectativas de los agentes económicos y en los mercados financieros.
#
# Link del comunicado: https://www.banrep.gov.co/es/noticias/minutas-banrep-julio-2025

# %%
texto_banco_republica = """
Entre mayo y junio la inflación anual se redujo de 5,1% a 4,8%. Esta disminución fue impulsada por la moderación de la inflación de las canastas de alimentos y de regulados.  En el caso de alimentos su inflación cayó de 4,7% a 4,3%, debido principalmente a la reducción de la inflación de perecederos. En cuanto a los regulados, su inflación se redujo de 6,3% a 5,5%, jalonada por la menor inflación de servicios públicos, especialmente de energía eléctrica. La inflación básica (sin alimentos ni regulados) se estabilizó en 4,8%, interrumpiendo su tendencia descendente, como resultado de algunas alzas en bienes y servicios diversos. Las expectativas de inflación se mantuvieron por encima de la meta. En el caso de los analistas, según las encuestas de julio, éstas se sitúan en 4,7% y 3,8% en la mediana para finales de 2025 y 2026 respectivamente. Las expectativas obtenidas de los mercados de deuda pública muestran comportamientos mixtos.
La actividad económica continúa con el dinamismo observado en el primer trimestre cuando alcanzó un crecimiento de 2,7% anual. En efecto, el índice de seguimiento de la economía (ISE) presentó en mayo una variación anual del 2,7% liderado por las actividades terciarias. Otros indicadores como las ventas al por menor, la producción manufacturera, y la demanda de energía, también mostraron resultados positivos. Sobre esta base, el equipo técnico estima que en el segundo trimestre la actividad económica crecería a un ritmo anual de 2,7%, jalonado por una demanda interna que se expandiría 4,1%.
Las condiciones de financiamiento externo del país se mantienen restrictivas, en un entorno de elevada incertidumbre mundial por los conflictos en varias regiones del mundo; tensiones comerciales globales que no obstante se han moderado; y la lenta normalización esperada de la política monetaria en los Estados Unidos. Respecto a estas dos últimas, las recientes negociaciones comerciales entre los Estados Unidos y otras economías como China, Reino Unido y la Unión Europea han acordado aranceles más bajos que los inicialmente anunciados. De otra parte, en los Estados Unidos la Reserva Federal (Fed) mantuvo inalterada la tasa de interés de política monetaria entre el 4,25 % y 4,5 % en su sesión de julio.
Los directores de la Junta coincidieron en destacar el buen desempeño que la economía colombiana ha venido mostrando en lo corrido del año, caracterizado por una actividad económica dinámica y una reducción de la tasa de desempleo, en un contexto en el que el crédito comienza a mostrar tasas de crecimiento reales positivas. Resaltaron el fortalecimiento de la demanda interna impulsada principalmente por el consumo privado. Reconocieron que el ritmo de descenso de la inflación en la primera mitad de 2025 ha sido más lento que el esperado, en un entorno de choques de origen externo que han tornado las condiciones financieras internacionales especialmente restrictivas. Señalaron que el persistente desajuste fiscal crea retos importantes para el país. En estas condiciones, cuatro miembros de la Junta se inclinaron por mantener inalterada la tasa de interés de política en 9,25%, dos de ellos votaron por una reducción de 50 pbs, y uno por un recorte de 25 pbs.

Los miembros del grupo mayoritario señalaron que la reducción de la inflación anual observada en junio y las perspectivas sobre su trayectoria en los próximos meses, no crean las condiciones propicias para proceder con un recorte de la tasa de interés de política. Advierten que se trató de un resultado de origen puntual que no asegura la convergencia de la inflación hacia la meta del 3% en un horizonte prudente. Al respecto, anotaron que la inflación básica (sin alimentos ni regulados) se mantuvo inalterada en junio, y que las expectativas de inflación para fines de 2025 y 2026 medidas en julio no se redujeron con respecto a las que existían en mayo. El equipo técnico proyecta una inflación total y básica de 4,7% y 4,2% para 2025 y de 3,2% y 3,3% para 2026 respectivamente. No obstante, estos directores resaltaron que se vislumbran riesgos inflacionarios a corto plazo de llegarse a presentar faltantes de financiamiento del déficit fiscal o de la cuenta corriente de la balanza de pagos que presionen al alza la tasa de cambio. Añadieron que un incremento sustancial del salario mínimo para 2026 en línea con lo ocurrido en años anteriores constituiría nuevamente un obstáculo para acercarse a la meta de inflación. Con respecto al panorama fiscal, subrayaron que el mayor déficit del Gobierno Central previsto para 2025 y para 2026 genera un impulso macroeconómico que se reflejaría en mayores presiones inflacionarias y en un incremento adicional a la ya alta prima de riesgo país. Señalaron que el favorable desempeño macroeconómico en materia de crecimiento y empleo de la primera mitad del año reduce los dilemas de política monetaria, lo cual permite que ésta se enfoque en el objetivo de buscar la convergencia de la inflación a la meta, mediante decisiones cautelosas sobre la tasa de interés, sin grandes sacrificios económicos a corto plazo y con la perspectiva de lograr la estabilidad de precios. Insistieron en que la inflación constituye un impuesto altamente regresivo que afecta desproporcionadamente a los hogares en condición de pobreza y en que los países que han consolidado la estabilidad de precios tienden a registrar mayores tasas de crecimiento, en buena medida porque logran mantener tasas de interés reales más bajas en el tiempo.

Los directores que votaron por una reducción de 50 pbs sostienen que la tasa de interés real de política monetaria descontando la inflación observada (tasa ex-post), del último año y medio (de enero del 2024 a junio del 2025) es 9,2 veces superior al promedio entre enero del 2010 y diciembre del 2023. La primera fue de 4,15% y la segunda 0,45%. Agregan que actualmente ésta se ubica en 4,4%, la segunda más alta de la región después de Brasil. Basados en esta evidencia, señalan que la postura de política monetaria en Colombia es altamente restrictiva. En segundo término, consideran que los cálculos de variables inobservables, tales como la tasa de interés neutral; la brecha del PIB; y la brecha de desempleo, que el equipo técnico utiliza para respaldar sus recomendaciones a la Junta, son discutibles por estar basadas en resultados de modelos, que no pueden verificarse empíricamente.  Argumentan que la inflación anual se ubicó en 4,82% en junio, reduciéndose frente al registro de mayo (5,05%) y sorprendiendo a la baja a los analistas del mercado. Aunque aún se encuentra por encima del rango meta, la trayectoria descendente refuerza el espacio para continuar con la reducción de tasas. El equipo técnico de la Dirección General de Política Macroeconómica del Ministerio de Hacienda (DGPM) proyecta en su última actualización de supuestos macroeconómicos que la inflación se sitúe en 4,5% al cierre de 2025. Las expectativas de inflación para cierre de 2025 se ubican en 4,79% en julio, disminuyendo 2pbs frente a lo esperado el mes pasado (4,81%). Además, las expectativas a 12 y 24 meses se mantienen ancladas en el rango meta del Banco de la República, ubicándose en 3,79% y 3,49% respectivamente, lo que sugiere espacio para mantener la senda de recortes de la tasa de interés. La tasa de interés real se ubicaría en 4,6% en julio, 2,0pps por encima del nivel neutral estimado por el Banco de la República (2,6%). Dado que se espera que la inflación mantenga su senda decreciente durante el resto del año y que la brecha del producto se ubique en terreno negativo, se considera apropiado continuar implementando reducciones en la tasa de interés en las próximas reuniones de la JDBR. Insisten en que tasas de interés reales altas como las que actualmente se observan en Colombia afectan las posibilidades de crecimiento económico, y en particular el dinamismo del sector manufacturero, que requiere incentivos mayores, se considera que continuar con la trayectoria de reducciones en la tasa de interés favorecería el impulso del sector industrial sobre el crecimiento económico. Agregaron que una reducción de tasas de interés también ofrecería un estímulo importante para el microcrédito y la economía popular.  De igual forma sustentan que los incrementos en el salario mínimo real en los últimos tres años no han tenido los efectos inflacionarios insinuados y, por otro lado, han contribuido a la reducción de los indicadores de pobreza, como se evidencia en la tasa de desempleo decreciente y reducción de la pobreza monetaria. Para atender los desequilibrios fiscales es prioritario garantizar el mayor crecimiento de la economía y una ley de financiamiento que permita la sostenibilidad fiscal en el mediano plazo.

El director que votó por un recorte de 25 pbs considera que cumplir el mandato constitucional de controlar la inflación se realiza en el contexto de cumplir con el objetivo principal de la política económica que es mantener un crecimiento sostenido y aumentar el empleo, especialmente en un país muy desigual como Colombia. Concuerda en que si bien, la coyuntura fiscal es compleja, se distancia de las expectativas excesivamente negativas sobre un posible deterioro fiscal, y valora la transparencia del Gobierno en este campo. Subraya que, a pesar de la activación de la cláusula de escape de la regla fiscal y de la reducción de la calificación crediticia, la prima de riesgo ha venido disminuyendo en las últimas semanas, corrigiendo desviaciones previas, como lo muestra el reciente descenso del CDS. Adicionalmente, observa que la tasa de cambio ha permanecido en sendas por debajo de los 4.200 pesos, y converge a las variaciones de otros países de la región, dando con ello señales de estabilidad. Finalmente advierte que, si bien las variables macroeconómicas continúan en una senda positiva, la inversión privada disminuye en algunos sectores tradicionales, razón por la cual es importante dar señales que permitan dar confianza a la inversión, para lo cual la tasa de interés de política cumple una función esencial.
"""

# %% [markdown]
# ## Preprocesamiento del Texto: La Limpieza de Datos
#
# Este es el paso más importante. Un texto 'sucio' puede llevar a conclusiones erróneas. Seguiremos una rutina estándar:

# %% [markdown]
# ### 1. Normalización
#
# Convertir todo a minúsculas para que 'Inflación' e 'inflación' se traten como la misma palabra.

# %%
texto_limpio = texto_banco_republica.lower()
texto_limpio
# Out:
# '\nentre mayo y junio la inflación anual se redujo de 5,1% a 4,8%. esta disminución fue impulsada por la moderación de la inflación de las canastas de alimentos y de regulados.  en el caso de alimentos su inflación cayó de 4,7% a 4,3%, debido principalmente a la reducción de la inflación de perecederos. en cuanto a los regulados, su inflación se redujo de 6,3% a 5,5%, jalonada por la menor inflación de servicios públicos, especialmente de energía eléctrica. la inflación básica (sin alimentos ni regulados) se estabilizó en 4,8%, interrumpiendo su tendencia descendente, como resultado de algunas alzas en bienes y servicios diversos. las expectativas de inflación se mantuvieron por encima de la meta. en el caso de los analistas, según las encuestas de julio, éstas se sitúan en 4,7% y 3,8% en la mediana para finales de 2025 y 2026 respectivamente. las expectativas obtenidas de los mercados de deuda pública muestran comportamientos mixtos.\nla actividad económica continúa con el dinamismo observado en el primer trimestre cuando alcanzó un crecimiento de 2,7% anual. en efecto, el índice de seguimiento de la economía (ise) presentó en mayo una variación anual del 2,7% liderado por las actividades terciarias. otros indicadores como las ventas al por menor, la producción manufacturera, y la demanda de energía, también mostraron resultados positivos. sobre esta base, el equipo técnico estima que en el segundo trimestre la actividad económica crecería a un ritmo anual de 2,7%, jalonado por una demanda interna que se expandiría 4,1%.\nlas condiciones de financiamiento externo del país se mantienen restrictivas, en un entorno de elevada incertidumbre mundial por los conflictos en varias regiones del mundo; tensiones comerciales globales que no obstante se han moderado; y la lenta normalización esperada de la política monetaria en los estados unidos. respecto a estas dos últimas, las recientes negociaciones comerciales entre los estados unidos y otras economías como china, reino unido y la unión europea han acordado aranceles más bajos que los inicialmente anunciados. de otra parte, en los estados unidos la reserva federal (fed) mantuvo inalterada la tasa de interés de política monetaria entre el 4,25 % y 4,5 % en su sesión de julio.\nlos directores de la junta coincidieron en destacar el buen desempeño que la economía colombiana ha venido mostrando en lo corrido del año, caracterizado por una actividad económica dinámica y una reducción de la tasa de desempleo, en un contexto en el que el crédito comienza a mostrar tasas de crecimiento reales positivas. resaltaron el fortalecimiento de la demanda interna impulsada principalmente por el consumo privado. reconocieron que el ritmo de descenso de la inflación en la primera mitad de 2025 ha sido más lento que el esperado, en un entorno de choques de origen externo que han tornado las condiciones financieras internacionales especialmente restrictivas. señalaron que el persistente desajuste fiscal crea retos importantes para el país. en estas condiciones, cuatro miembros de la junta se inclinaron por mantener inalterada la tasa de interés de política en 9,25%, dos de ellos votaron por una reducción de 50 pbs, y uno por un recorte de 25 pbs.\n\nlos miembros del grupo mayoritario señalaron que la reducción de la inflación anual observada en junio y las perspectivas sobre su trayectoria en los próximos meses, no crean las condiciones propicias para proceder con un recorte de la tasa de interés de política. advierten que se trató de un resultado de origen puntual que no asegura la convergencia de la inflación hacia la meta del 3% en un horizonte prudente. al respecto, anotaron que la inflación básica (sin alimentos ni regulados) se mantuvo inalterada en junio, y que las expectativas de inflación para fines de 2025 y 2026 medidas en julio no se redujeron con respecto a las que existían en mayo. el equipo técnico proyecta una inflación total y básica de 4,7% y 4,2% para 2025 y de 3,2% y 3,3% para 2026  ...

# %% [markdown]
# ### 2. Limpieza de caracteres no alfabéticos
#
# Usamos expresiones regulares para quitar puntuación y números.

# %% [markdown]
# re.sub(patrón, reemplazo, texto) → busca todas las coincidencias de un patrón regex en el texto y las reemplaza por el valor que le indiques.
#
# En este caso:
#
# - patrón = r'[^a-záéíóúñ\s]'
#
# - reemplazo = '' (una cadena vacía → borra lo encontrado)
#
# - texto = texto_limpio
#
# Explicación del patrón r'[^a-záéíóúñ\s]':
#
# - [] → define un conjunto de caracteres permitidos.
#
# - ^ (dentro de []) → significa “no” (niega lo que sigue).
#
# - a-z → letras minúsculas de la a a la z.
#
# - áéíóúñ → se añaden explícitamente vocales con tilde y la ñ, comunes en español.
#
# - \s → representa espacios en blanco (incluye espacio, tabulador, salto de línea).

# %%
texto_limpio = re.sub(r'[^a-záéíóúñ\s]', '', texto_limpio)
texto_limpio
# Out:
# '\nentre mayo y junio la inflación anual se redujo de  a  esta disminución fue impulsada por la moderación de la inflación de las canastas de alimentos y de regulados  en el caso de alimentos su inflación cayó de  a  debido principalmente a la reducción de la inflación de perecederos en cuanto a los regulados su inflación se redujo de  a  jalonada por la menor inflación de servicios públicos especialmente de energía eléctrica la inflación básica sin alimentos ni regulados se estabilizó en  interrumpiendo su tendencia descendente como resultado de algunas alzas en bienes y servicios diversos las expectativas de inflación se mantuvieron por encima de la meta en el caso de los analistas según las encuestas de julio éstas se sitúan en  y  en la mediana para finales de  y  respectivamente las expectativas obtenidas de los mercados de deuda pública muestran comportamientos mixtos\nla actividad económica continúa con el dinamismo observado en el primer trimestre cuando alcanzó un crecimiento de  anual en efecto el índice de seguimiento de la economía ise presentó en mayo una variación anual del  liderado por las actividades terciarias otros indicadores como las ventas al por menor la producción manufacturera y la demanda de energía también mostraron resultados positivos sobre esta base el equipo técnico estima que en el segundo trimestre la actividad económica crecería a un ritmo anual de  jalonado por una demanda interna que se expandiría \nlas condiciones de financiamiento externo del país se mantienen restrictivas en un entorno de elevada incertidumbre mundial por los conflictos en varias regiones del mundo tensiones comerciales globales que no obstante se han moderado y la lenta normalización esperada de la política monetaria en los estados unidos respecto a estas dos últimas las recientes negociaciones comerciales entre los estados unidos y otras economías como china reino unido y la unión europea han acordado aranceles más bajos que los inicialmente anunciados de otra parte en los estados unidos la reserva federal fed mantuvo inalterada la tasa de interés de política monetaria entre el   y   en su sesión de julio\nlos directores de la junta coincidieron en destacar el buen desempeño que la economía colombiana ha venido mostrando en lo corrido del año caracterizado por una actividad económica dinámica y una reducción de la tasa de desempleo en un contexto en el que el crédito comienza a mostrar tasas de crecimiento reales positivas resaltaron el fortalecimiento de la demanda interna impulsada principalmente por el consumo privado reconocieron que el ritmo de descenso de la inflación en la primera mitad de  ha sido más lento que el esperado en un entorno de choques de origen externo que han tornado las condiciones financieras internacionales especialmente restrictivas señalaron que el persistente desajuste fiscal crea retos importantes para el país en estas condiciones cuatro miembros de la junta se inclinaron por mantener inalterada la tasa de interés de política en  dos de ellos votaron por una reducción de  pbs y uno por un recorte de  pbs\n\nlos miembros del grupo mayoritario señalaron que la reducción de la inflación anual observada en junio y las perspectivas sobre su trayectoria en los próximos meses no crean las condiciones propicias para proceder con un recorte de la tasa de interés de política advierten que se trató de un resultado de origen puntual que no asegura la convergencia de la inflación hacia la meta del  en un horizonte prudente al respecto anotaron que la inflación básica sin alimentos ni regulados se mantuvo inalterada en junio y que las expectativas de inflación para fines de  y  medidas en julio no se redujeron con respecto a las que existían en mayo el equipo técnico proyecta una inflación total y básica de  y  para  y de  y  para  respectivamente no obstante estos directores resaltaron que se vislumbran riesgos inflacionarios a corto plazo de llegarse a presentar faltantes de financiamiento del déficit f ...

# %% [markdown]
# ### 3. Tokenización
#
# Dividir el texto en una lista de palabras individuales (tokens).

# %%
tokens = word_tokenize(texto_limpio, 'spanish')
tokens
# Out:
# ['entre',
#  'mayo',
#  'y',
#  'junio',
#  'la',
#  'inflación',
#  'anual',
#  'se',
#  'redujo',
#  'de',
#  'a',
#  'esta',
#  'disminución',
#  'fue',
#  'impulsada',
#  'por',
#  'la',
#  'moderación',
#  'de',
#  'la',
#  'inflación',
#  'de',
#  'las',
#  'canastas',
#  'de',
#  'alimentos',
#  'y',
#  'de',
#  'regulados',
#  'en',
#  'el',
#  'caso',
#  'de',
#  'alimentos',
#  'su',
#  'inflación',
#  'cayó',
#  'de',
#  'a',
#  'debido',
#  'principalmente',
#  'a',
#  'la',
#  'reducción',
#  'de',
#  'la',
#  'inflación',
#  'de',
#  'perecederos',
#  'en',
#  'cuanto',
#  'a',
#  'los',
#  'regulados',
#  'su',
#  'inflación',
#  'se',
#  'redujo',
#  'de',
#  'a',
#  'jalonada',
#  'por',
#  'la',
#  'menor',
#  'inflación',
#  'de',
#  'servicios',
#  'públicos',
#  'especialmente',
#  'de',
#  'energía',
#  'eléctrica',
#  'la',
#  'inflación',
#  'básica',
#  'sin',
#  'alimentos',
#  'ni',
#  'regulados',
#  'se',
#  'estabilizó',
#  'en',
#  'interrumpiendo',
#  'su',
#  'tendencia',
#  'descendente',
#  'como',
#  'resultado',
#  'de',
#  'algunas',
#  'alzas',
#  'en',
#  'bienes',
#  'y',
#  'servicios',
#  'diversos',
#  'las',
#  'expectativas',
#  'de',
#  'inflación',
#  'se',
#  'mantuvieron',
#  'por',
#  'encima',
#  'de',
#  'la',
#  'meta',
#  'en',
#  'el',
#  'caso',
#  'de',
#  'los',
#  'analistas',
#  'según',
#  'las',
#  'encuestas',
#  'de',
#  'julio',
#  'éstas',
#  'se',
#  'sitúan',
#  'en',
#  'y',
#  'en',
#  'la',
#  'mediana',
#  'para',
#  'finales',
#  'de',
#  'y',
#  'respectivamente',
#  'las',
#  'expectativas',
#  'obtenidas',
#  'de',
#  'los',
#  'mercados',
#  'de',
#  'deuda',
#  'pública',
#  'muestran',
#  'comportamientos',
#  'mixtos',
#  'la',
#  'actividad',
#  'económica',
#  'continúa',
#  'con',
#  'el',
#  'dinamismo',
#  'observado',
#  'en',
#  'el',
#  'primer',
#  'trimestre',
#  'cuando',
#  'alcanzó',
#  'un',
#  'crecimiento',
#  'de',
#  'anual',
#  'en',
#  'efecto',
#  'el',
#  'índice',
#  'de',
#  'seguimiento',
#  'de',
#  'la',
#  'economía',
#  'ise',
#  'presentó',
#  'en',
#  'mayo',
#  'una',
#  'variación',
#  'anual',
#  'del',
#  'liderado',
#  'por',
#  'las',
#  'actividades',
#  'terciarias',
#  'otros',
#  'indicadores',
#  'como',
#  'las',
#  'ventas',
#  'al',
#  'por',
#  'menor',
#  'la',
#  'producción',
#  'manufacturera',
#  'y',
#  'la',
#  'demanda',
#  'de',
#  'energía',
#  'también',
#  'mostraron',
#  'resultados',
#  'positivos',
#  'sobre',
#  'esta',
#  'base',
#  'el',
#  'equipo',
#  'técnico',
#  'estima',
#  'que',
#  'en',
#  'el',
#  'segundo',
#  'trimestre',
#  'la',
#  'actividad',
#  'económica',
#  'crecería',
#  'a',
#  'un',
#  'ritmo',
#  'anual',
#  'de',
#  'jalonado',
#  'por',
#  'una',
#  'demanda',
#  'interna',
#  'que',
#  'se',
#  'expandiría',
#  'las',
#  'condiciones',
#  'de',
#  'financiamiento',
#  'externo',
#  'del',
#  'país',
#  'se',
#  'mantienen',
#  'restrictivas',
#  'en',
#  'un',
#  'entorno',
#  'de',
#  'elevada',
#  'incertidumbre',
#  'mundial',
#  'por',
#  'los',
#  'conflictos',
#  'en',
#  'varias',
#  'regiones',
#  'del',
#  'mundo',
#  'tensiones',
#  'comerciales',
#  'globales',
#  'que',
#  'no',
#  'obstante',
#  'se',
#  'han',
#  'moderado',
#  'y',
#  'la',
#  'lenta',
#  'normalización',
#  'esperada',
#  'de',
#  'la',
#  'política',
#  'monetaria',
#  'en',
#  'los',
#  'estados',
#  'unidos',
#  'respecto',
#  'a',
#  'estas',
#  'dos',
#  'últimas',
#  'las',
#  'recientes',
#  'negociaciones',
#  'comerciales',
#  'entre',
#  'los',
#  'estados',
#  'unidos',
#  'y',
#  'otras',
#  'economías',
#  'como',
#  'china',
#  'reino',
#  'unido',
#  'y',
#  'la',
#  'unión',
#  'europea',
#  'han',
#  'acordado',
#  'aranceles',
#  'más',
#  'bajos',
#  'que',
#  'los',
#  'inicialmente',
#  'anunciados',
#  'de',
#  'otra',
#  'parte',
#  'en',
#  'los',
#  'estados',
#  'unidos',
#  'la',
#  'reserva',
#  'federal',
#  'fed',
#  'mantuvo',
#  'inalterada',
#  'la',
#  'tasa',
#  'de',
#  'interés',
#  'de',
#  'política',
#  'monetaria',
#  'entre',
#  'el',
#  'y',
#  'en',
#  'su',
#  'sesión',
#  'de',
#  'julio',
#  'los',
#  'directores',
#  'de',
#  'la',
#  'junta',
#  'coincidieron',
#  'en',
#  'destacar',
#  'el',
#  'buen',
#  'desempeño',
#  'que',
#  'la',
#  'economía',
#  'colombiana',
#  'ha',
#  'venido',
#  'mostrando',
#  'en',
#  'lo',
#  'corrido',
#  'del',
#  'año',
#  'caracterizado',
#  'por',
#  'una',
#  'actividad',
#  'económica',
#  'dinámica',
#  'y',
#  'una',
#  'reducción',
#  'de',
#  'la',
#  'tasa',
#  'de',
#  'desempleo',
#  'en',
#  'un',
#  'contexto',
#  'en',
#  'el',
#  'que',
#  'el',
#  'crédito',
#  'comienza',
#  'a',
#  'mostrar',
#  'tasas',
#  'de',
#  'crecimiento',
#  'reales',
#  'positivas',
#  'resaltaron',
#  'el',
#  'fortalecimiento',
#  'de',
#  'la',
#  'demanda',
#  'interna',
#  'impulsada',
#  'principalmente',
#  'por',
#  'el',
#  'consumo',
#  'privado',
#  'reconocieron',
#  'que',
#  'el',
#  'ritmo',
#  'de',
#  'descenso',
#  'de',
#  'la',
#  'inflación',
#  'en',
#  'la',
#  'primera',
#  'mitad',
#  'de',
#  'ha',
#  'sido',
#  'más',
#  'lento',
#  'que',
#  'el',
#  'esperado',
#  'en',
#  'un',
#  'entorno',
#  'de',
#  'choques',
#  'de',
#  'origen',
#  'externo',
#  'que',
#  'han',
#  'tornado',
#  'las',
#  'condiciones',
#  'financieras',
#  'internacionales',
#  'especialmente',
#  'restrictivas',
#  'señalaron',
#  'que',
#  'el',
#  'persistente',
#  'desajuste',
#  'fiscal',
#  'crea',
#  'retos',
#  'importantes',
#  'para',
#  'el',
#  'país',
#  'en',
#  'estas',
#  'condiciones',
#  'cuatro',
#  'miembros',
#  'de',
#  'la',
#  'junta',
#  'se',
#  'inclinaron',
#  'por',
#  'mantener',
#  'inalterada',
#  'la',
#  'tasa',
#  'de',
#  'interés',
#  'de',
#  'política',
#  'en',
#  'dos',
#  'de',
#  'ellos',
#  'votaron',
#  'por',
#  'una',
#  'reducción',
#  'de',
#  'pbs',
#  'y',
#  'uno',
#  'por',
#  'un',
#  'recorte',
#  'de',
#  'pbs',
#  'los',
#  'miembros',
#  'del',
#  'grupo',
#  'mayoritario',
#  'señalaron',
#  'que',
#  'la',
#  'reducción',
#  'de',
#  'la',
#  'inflación',
#  'anual',
#  'observada',
#  'en',
#  'junio',
#  'y',
#  'las',
#  'perspectivas',
#  'sobre',
#  'su',
#  'trayectoria',
#  'en',
#  'los',
#  'próximos',
#  'meses',
#  'no',
#  'crean',
#  'las',
#  'condiciones',
#  'propicias',
#  'para',
#  'proceder',
#  'con',
#  'un',
#  'recorte',
#  'de',
#  'la',
#  'tasa',
#  'de',
#  'interés',
#  'de',
#  'política',
#  'advierten',
#  'que',
#  'se',
#  'trató',
#  'de',
#  'un',
#  'resultado',
#  'de',
#  'origen',
#  'puntual',
#  'que',
#  'no',
#  'asegura',
#  'la',
#  'convergencia',
#  'de',
#  'la',
#  'inflación',
#  'hacia',
#  'la',
#  'meta',
#  'del',
#  'en',
#  'un',
#  'horizonte',
#  'prudente',
#  'al',
#  'respecto',
#  'anotaron',
#  'que',
#  'la',
#  'inflación',
#  'básica',
#  'sin',
#  'alimentos',
#  'ni',
#  'regulados',
#  'se',
#  'mantuvo',
#  'inalterada',
#  'en',
#  'junio',
#  'y',
#  'que',
#  'las',
#  'expectativas',
#  'de',
#  'inflación',
#  'para',
#  'fines',
#  'de',
#  'y',
#  'medidas',
#  'en',
#  'julio',
#  'no',
#  'se',
#  'redujeron',
#  'con',
#  'respecto',
#  'a',
#  'las',
#  'que',
#  'existían',
#  'en',
#  'mayo',
#  'el',
#  'equipo',
#  'técnico',
#  'proyecta',
#  'una',
#  'inflación',
#  'total',
#  'y',
#  'básica',
#  'de',
#  'y',
#  'para',
#  'y',
#  'de',
#  'y',
#  'para',
#  'respectivamente',
#  'no',
#  'obstante',
#  'estos',
#  'directores',
#  'resaltaron',
#  'que',
#  'se',
#  'vislumbran',
#  'riesgos',
#  'inflacionarios',
#  'a',
#  'corto',
#  'plazo',
#  'de',
#  'llegarse',
#  'a',
#  'presentar',
#  'faltantes',
#  'de',
#  'financiamiento',
#  'del',
#  'déficit',
#  'fiscal',
#  'o',
#  'de',
#  'la',
#  'cuenta',
#  'corriente',
#  'de',
#  'la',
#  'balanza',
#  'de',
#  'pagos',
#  'que',
#  'presionen',
#  'al',
#  'alza',
#  'la',
#  'tasa',
#  'de',
#  'cambio',
#  'añadieron',
#  'que',
#  'un',
#  'incremento',
#  'sustancial',
#  'del',
#  'salario',
#  'mínimo',
#  'para',
#  'en',
#  'línea',
#  'con',
#  'lo',
#  'ocurrido',
#  'en',
#  'años',
#  'anteriores',
#  'constituiría',
#  'nuevamente',
#  'un',
#  'obstáculo',
#  'para',
#  'acercarse',
#  'a',
#  'la',
#  'meta',
#  'de',
#  'inflación',
#  'con',
#  'respecto',
#  'al',
#  'panorama',
#  'fiscal',
#  'subrayaron',
#  'que',
#  'el',
#  'mayor',
#  'déficit',
#  'del',
#  'gobierno',
#  'central',
#  'previsto',
#  'para',
#  'y',
#  'para',
#  'genera',
#  'un',
#  'impulso',
#  'macroeconómico',
#  'que',
#  'se',
#  'reflejaría',
#  'en',
#  'mayores',
#  'presiones',
#  'inflacionarias',
#  'y',
#  'en',
#  'un',
#  'incremento',
#  'adicional',
#  'a',
#  'la',
#  'ya',
#  'alta',
#  'prima',
#  'de',
#  'riesgo',
#  'país',
#  'señalaron',
#  'que',
#  'el',
#  'favorable',
#  'desempeño',
#  'macroeconómico',
#  'en',
#  'materia',
#  'de',
#  'crecimiento',
#  'y',
#  'empleo',
#  'de',
#  'la',
#  'primera',
#  'mitad',
#  'del',
#  'año',
#  'reduce',
#  'los',
#  'dilemas',
#  'de',
#  'política',
#  'monetaria',
#  'lo',
#  'cual',
#  'permite',
#  'que',
#  'ésta',
#  'se',
#  'enfoque',
#  'en',
#  'el',
#  'objetivo',
#  'de',
#  'buscar',
#  'la',
#  'convergencia',
#  'de',
#  'la',
#  'inflación',
#  'a',
#  'la',
#  'meta',
#  'mediante',
#  'decisiones',
#  'cautelosas',
#  'sobre',
#  'la',
#  'tasa',
#  'de',
#  'interés',
#  'sin',
#  'grandes',
#  'sacrificios',
#  'económicos',
#  'a',
#  'corto',
#  'plazo',
#  'y',
#  'con',
#  'la',
#  'perspectiva',
#  'de',
#  'lograr',
#  'la',
#  'estabilidad',
#  'de',
#  'precios',
#  'insistieron',
#  'en',
#  'que',
#  'la',
#  'inflación',
#  'constituye',
#  'un',
#  'impuesto',
#  'altamente',
#  'regresivo',
#  'que',
#  'afecta',
#  'desproporcionadamente',
#  'a',
#  'los',
#  'hogares',
#  'en',
#  'condición',
#  'de',
#  'pobreza',
#  'y',
#  'en',
#  'que',
#  'los',
#  'países',
#  'que',
#  'han',
#  'consolidado',
#  'la',
#  'estabilidad',
#  'de',
#  'precios',
#  'tienden',
#  'a',
#  'registrar',
#  'mayores',
#  'tasas',
#  'de',
#  'crecimiento',
#  'en',
#  'buena',
#  'medida',
#  'porque',
#  'logran',
#  'mantener',
#  'tasas',
#  'de',
#  'interés',
#  'reales',
#  'más',
#  'bajas',
#  'en',
#  'el',
#  'tiempo',
#  'los',
#  'directores',
#  'que',
#  'votaron',
#  'por',
#  'una',
#  'reducción',
#  'de',
#  'pbs',
#  'sostienen',
#  'que',
#  'la',
#  'tasa',
#  'de',
#  'interés',
#  'real',
#  'de',
#  'política',
#  'monetaria',
#  'descontando',
#  'la',
#  'inflación',
#  'observada',
#  'tasa',
#  'expost',
#  'del',
#  'último',
#  'año',
#  'y',
#  'medio',
#  'de',
#  'enero',
#  'del',
#  'a',
#  'junio',
#  'del',
#  'es',
#  'veces',
#  'superior',
#  'al',
#  'promedio',
#  'entre',
#  'enero',
#  'del',
#  'y',
#  'diciembre',
#  'del',
#  'la',
#  'primera',
#  'fue',
#  'de',
#  'y',
#  'la',
#  'segunda',
#  'agregan',
#  'que',
#  'actualmente',
#  'ésta',
#  'se',
#  'ubica',
#  'en',
#  'la',
#  'segunda',
#  'más',
#  'alta',
#  'de',
#  'la',
#  'región',
#  'después',
#  'de',
#  'brasil',
#  'basados',
#  'en',
#  'esta',
#  'evidencia',
#  'señalan',
#  'que',
#  'la',
#  'postura',
#  'de',
#  'política',
#  'monetaria',
#  'en',
#  'colombia',
#  'es',
#  'altamente',
#  'restrictiva',
#  'en',
#  'segundo',
#  'término',
#  'consideran',
#  'que',
#  'los',
#  'cálculos',
#  'de',
#  'variables',
#  'inobservables',
#  'tales',
#  'como',
#  'la',
#  'tasa',
#  'de',
#  'interés',
#  'neutral',
#  'la',
#  'brecha',
#  'del',
#  'pib',
#  'y',
#  'la',
#  'brecha',
#  'de',
#  'desempleo',
#  'que',
#  'el',
#  'equipo',
#  'técnico',
#  'utiliza',
#  'para',
#  'respaldar',
#  'sus',
#  'recomendaciones',
#  'a',
#  'la',
#  'junta',
#  'son',
#  'discutibles',
#  'por',
#  'estar',
#  'basadas',
#  'en',
#  'resultados',
#  'de',
#  'modelos',
#  'que',
#  'no',
#  'pueden',
#  'verificarse',
#  'empíricamente',
#  'argumentan',
#  'que',
#  'la',
#  'inflación',
#  'anual',
#  'se',
#  'ubicó',
#  'en',
#  'en',
#  'junio',
#  ...]

# %% [markdown]
# ### 4. Eliminación de Stop Words

# %% [markdown]
# En procesamiento de lenguaje natural (PLN), las stop words son palabras muy comunes en un idioma que, por lo general, no aportan mucho significado y se eliminan antes de hacer un análisis de texto.
#
# - Ejemplos en español:
#
#   - artículos: el, la, los, las, un, una
#
#   - preposiciones: en, de, con, para, por, sobre
#
#   - pronombres y conectores: que, se, lo, y, o, pero, como
#
# - ¿Por qué quitarlas?
#
# Si estás construyendo una nube de palabras o entrenando un modelo de machine learning, esas palabras aparecen con muchísima frecuencia y pueden ocultar las palabras realmente relevantes (ej. comida, servicio, lento, delicioso).
#
# - Ejemplo:
#
#   - Frase original: "El servicio fue excelente y la comida deliciosa"
#
#   - Después de eliminar stop words: "servicio excelente comida deliciosa"
#
# Así se destacan las palabras que llevan la información importante.

# %%
stop_words_es = set(stopwords.words('spanish'))
stop_words_es
# Out:
# {'a',
#  'al',
#  'algo',
#  'algunas',
#  'algunos',
#  'ante',
#  'antes',
#  'como',
#  'con',
#  'contra',
#  'cual',
#  'cuando',
#  'de',
#  'del',
#  'desde',
#  'donde',
#  'durante',
#  'e',
#  'el',
#  'ella',
#  'ellas',
#  'ellos',
#  'en',
#  'entre',
#  'era',
#  'erais',
#  'eran',
#  'eras',
#  'eres',
#  'es',
#  'esa',
#  'esas',
#  'ese',
#  'eso',
#  'esos',
#  'esta',
#  'estaba',
#  'estabais',
#  'estaban',
#  'estabas',
#  'estad',
#  'estada',
#  'estadas',
#  'estado',
#  'estados',
#  'estamos',
#  'estando',
#  'estar',
#  'estaremos',
#  'estará',
#  'estarán',
#  'estarás',
#  'estaré',
#  'estaréis',
#  'estaría',
#  'estaríais',
#  'estaríamos',
#  'estarían',
#  'estarías',
#  'estas',
#  'este',
#  'estemos',
#  'esto',
#  'estos',
#  'estoy',
#  'estuve',
#  'estuviera',
#  'estuvierais',
#  'estuvieran',
#  'estuvieras',
#  'estuvieron',
#  'estuviese',
#  'estuvieseis',
#  'estuviesen',
#  'estuvieses',
#  'estuvimos',
#  'estuviste',
#  'estuvisteis',
#  'estuviéramos',
#  'estuviésemos',
#  'estuvo',
#  'está',
#  'estábamos',
#  'estáis',
#  'están',
#  'estás',
#  'esté',
#  'estéis',
#  'estén',
#  'estés',
#  'fue',
#  'fuera',
#  'fuerais',
#  'fueran',
#  'fueras',
#  'fueron',
#  'fuese',
#  'fueseis',
#  'fuesen',
#  'fueses',
#  'fui',
#  'fuimos',
#  'fuiste',
#  'fuisteis',
#  'fuéramos',
#  'fuésemos',
#  'ha',
#  'habida',
#  'habidas',
#  'habido',
#  'habidos',
#  'habiendo',
#  'habremos',
#  'habrá',
#  'habrán',
#  'habrás',
#  'habré',
#  'habréis',
#  'habría',
#  'habríais',
#  'habríamos',
#  'habrían',
#  'habrías',
#  'habéis',
#  'había',
#  'habíais',
#  'habíamos',
#  'habían',
#  'habías',
#  'han',
#  'has',
#  'hasta',
#  'hay',
#  'haya',
#  'hayamos',
#  'hayan',
#  'hayas',
#  'hayáis',
#  'he',
#  'hemos',
#  'hube',
#  'hubiera',
#  'hubierais',
#  'hubieran',
#  'hubieras',
#  'hubieron',
#  'hubiese',
#  'hubieseis',
#  'hubiesen',
#  'hubieses',
#  'hubimos',
#  'hubiste',
#  'hubisteis',
#  'hubiéramos',
#  'hubiésemos',
#  'hubo',
#  'la',
#  'las',
#  'le',
#  'les',
#  'lo',
#  'los',
#  'me',
#  'mi',
#  'mis',
#  'mucho',
#  'muchos',
#  'muy',
#  'más',
#  'mí',
#  'mía',
#  'mías',
#  'mío',
#  'míos',
#  'nada',
#  'ni',
#  'no',
#  'nos',
#  'nosotras',
#  'nosotros',
#  'nuestra',
#  'nuestras',
#  'nuestro',
#  'nuestros',
#  'o',
#  'os',
#  'otra',
#  'otras',
#  'otro',
#  'otros',
#  'para',
#  'pero',
#  'poco',
#  'por',
#  'porque',
#  'que',
#  'quien',
#  'quienes',
#  'qué',
#  'se',
#  'sea',
#  'seamos',
#  'sean',
#  'seas',
#  'sentid',
#  'sentida',
#  'sentidas',
#  'sentido',
#  'sentidos',
#  'seremos',
#  'será',
#  'serán',
#  'serás',
#  'seré',
#  'seréis',
#  'sería',
#  'seríais',
#  'seríamos',
#  'serían',
#  'serías',
#  'seáis',
#  'siente',
#  'sin',
#  'sintiendo',
#  'sobre',
#  'sois',
#  'somos',
#  'son',
#  'soy',
#  'su',
#  'sus',
#  'suya',
#  'suyas',
#  'suyo',
#  'suyos',
#  'sí',
#  'también',
#  'tanto',
#  'te',
#  'tendremos',
#  'tendrá',
#  'tendrán',
#  'tendrás',
#  'tendré',
#  'tendréis',
#  'tendría',
#  'tendríais',
#  'tendríamos',
#  'tendrían',
#  'tendrías',
#  'tened',
#  'tenemos',
#  'tenga',
#  'tengamos',
#  'tengan',
#  'tengas',
#  'tengo',
#  'tengáis',
#  'tenida',
#  'tenidas',
#  'tenido',
#  'tenidos',
#  'teniendo',
#  'tenéis',
#  'tenía',
#  'teníais',
#  'teníamos',
#  'tenían',
#  'tenías',
#  'ti',
#  'tiene',
#  'tienen',
#  'tienes',
#  'todo',
#  'todos',
#  'tu',
#  'tus',
#  'tuve',
#  'tuviera',
#  'tuvierais',
#  'tuvieran',
#  'tuvieras',
#  'tuvieron',
#  'tuviese',
#  'tuvieseis',
#  'tuviesen',
#  'tuvieses',
#  'tuvimos',
#  'tuviste',
#  'tuvisteis',
#  'tuviéramos',
#  'tuviésemos',
#  'tuvo',
#  'tuya',
#  'tuyas',
#  'tuyo',
#  'tuyos',
#  'tú',
#  'un',
#  'una',
#  'uno',
#  'unos',
#  'vosotras',
#  'vosotros',
#  'vuestra',
#  'vuestras',
#  'vuestro',
#  'vuestros',
#  'y',
#  'ya',
#  'yo',
#  'él',
#  'éramos'}

# %%
tokens_filtrados = [palabra for palabra in tokens if palabra not in stop_words_es]
tokens_filtrados
# Out:
# ['mayo',
#  'junio',
#  'inflación',
#  'anual',
#  'redujo',
#  'disminución',
#  'impulsada',
#  'moderación',
#  'inflación',
#  'canastas',
#  'alimentos',
#  'regulados',
#  'caso',
#  'alimentos',
#  'inflación',
#  'cayó',
#  'debido',
#  'principalmente',
#  'reducción',
#  'inflación',
#  'perecederos',
#  'cuanto',
#  'regulados',
#  'inflación',
#  'redujo',
#  'jalonada',
#  'menor',
#  'inflación',
#  'servicios',
#  'públicos',
#  'especialmente',
#  'energía',
#  'eléctrica',
#  'inflación',
#  'básica',
#  'alimentos',
#  'regulados',
#  'estabilizó',
#  'interrumpiendo',
#  'tendencia',
#  'descendente',
#  'resultado',
#  'alzas',
#  'bienes',
#  'servicios',
#  'diversos',
#  'expectativas',
#  'inflación',
#  'mantuvieron',
#  'encima',
#  'meta',
#  'caso',
#  'analistas',
#  'según',
#  'encuestas',
#  'julio',
#  'éstas',
#  'sitúan',
#  'mediana',
#  'finales',
#  'respectivamente',
#  'expectativas',
#  'obtenidas',
#  'mercados',
#  'deuda',
#  'pública',
#  'muestran',
#  'comportamientos',
#  'mixtos',
#  'actividad',
#  'económica',
#  'continúa',
#  'dinamismo',
#  'observado',
#  'primer',
#  'trimestre',
#  'alcanzó',
#  'crecimiento',
#  'anual',
#  'efecto',
#  'índice',
#  'seguimiento',
#  'economía',
#  'ise',
#  'presentó',
#  'mayo',
#  'variación',
#  'anual',
#  'liderado',
#  'actividades',
#  'terciarias',
#  'indicadores',
#  'ventas',
#  'menor',
#  'producción',
#  'manufacturera',
#  'demanda',
#  'energía',
#  'mostraron',
#  'resultados',
#  'positivos',
#  'base',
#  'equipo',
#  'técnico',
#  'estima',
#  'segundo',
#  'trimestre',
#  'actividad',
#  'económica',
#  'crecería',
#  'ritmo',
#  'anual',
#  'jalonado',
#  'demanda',
#  'interna',
#  'expandiría',
#  'condiciones',
#  'financiamiento',
#  'externo',
#  'país',
#  'mantienen',
#  'restrictivas',
#  'entorno',
#  'elevada',
#  'incertidumbre',
#  'mundial',
#  'conflictos',
#  'varias',
#  'regiones',
#  'mundo',
#  'tensiones',
#  'comerciales',
#  'globales',
#  'obstante',
#  'moderado',
#  'lenta',
#  'normalización',
#  'esperada',
#  'política',
#  'monetaria',
#  'unidos',
#  'respecto',
#  'dos',
#  'últimas',
#  'recientes',
#  'negociaciones',
#  'comerciales',
#  'unidos',
#  'economías',
#  'china',
#  'reino',
#  'unido',
#  'unión',
#  'europea',
#  'acordado',
#  'aranceles',
#  'bajos',
#  'inicialmente',
#  'anunciados',
#  'parte',
#  'unidos',
#  'reserva',
#  'federal',
#  'fed',
#  'mantuvo',
#  'inalterada',
#  'tasa',
#  'interés',
#  'política',
#  'monetaria',
#  'sesión',
#  'julio',
#  'directores',
#  'junta',
#  'coincidieron',
#  'destacar',
#  'buen',
#  'desempeño',
#  'economía',
#  'colombiana',
#  'venido',
#  'mostrando',
#  'corrido',
#  'año',
#  'caracterizado',
#  'actividad',
#  'económica',
#  'dinámica',
#  'reducción',
#  'tasa',
#  'desempleo',
#  'contexto',
#  'crédito',
#  'comienza',
#  'mostrar',
#  'tasas',
#  'crecimiento',
#  'reales',
#  'positivas',
#  'resaltaron',
#  'fortalecimiento',
#  'demanda',
#  'interna',
#  'impulsada',
#  'principalmente',
#  'consumo',
#  'privado',
#  'reconocieron',
#  'ritmo',
#  'descenso',
#  'inflación',
#  'primera',
#  'mitad',
#  'sido',
#  'lento',
#  'esperado',
#  'entorno',
#  'choques',
#  'origen',
#  'externo',
#  'tornado',
#  'condiciones',
#  'financieras',
#  'internacionales',
#  'especialmente',
#  'restrictivas',
#  'señalaron',
#  'persistente',
#  'desajuste',
#  'fiscal',
#  'crea',
#  'retos',
#  'importantes',
#  'país',
#  'condiciones',
#  'cuatro',
#  'miembros',
#  'junta',
#  'inclinaron',
#  'mantener',
#  'inalterada',
#  'tasa',
#  'interés',
#  'política',
#  'dos',
#  'votaron',
#  'reducción',
#  'pbs',
#  'recorte',
#  'pbs',
#  'miembros',
#  'grupo',
#  'mayoritario',
#  'señalaron',
#  'reducción',
#  'inflación',
#  'anual',
#  'observada',
#  'junio',
#  'perspectivas',
#  'trayectoria',
#  'próximos',
#  'meses',
#  'crean',
#  'condiciones',
#  'propicias',
#  'proceder',
#  'recorte',
#  'tasa',
#  'interés',
#  'política',
#  'advierten',
#  'trató',
#  'resultado',
#  'origen',
#  'puntual',
#  'asegura',
#  'convergencia',
#  'inflación',
#  'hacia',
#  'meta',
#  'horizonte',
#  'prudente',
#  'respecto',
#  'anotaron',
#  'inflación',
#  'básica',
#  'alimentos',
#  'regulados',
#  'mantuvo',
#  'inalterada',
#  'junio',
#  'expectativas',
#  'inflación',
#  'fines',
#  'medidas',
#  'julio',
#  'redujeron',
#  'respecto',
#  'existían',
#  'mayo',
#  'equipo',
#  'técnico',
#  'proyecta',
#  'inflación',
#  'total',
#  'básica',
#  'respectivamente',
#  'obstante',
#  'directores',
#  'resaltaron',
#  'vislumbran',
#  'riesgos',
#  'inflacionarios',
#  'corto',
#  'plazo',
#  'llegarse',
#  'presentar',
#  'faltantes',
#  'financiamiento',
#  'déficit',
#  'fiscal',
#  'cuenta',
#  'corriente',
#  'balanza',
#  'pagos',
#  'presionen',
#  'alza',
#  'tasa',
#  'cambio',
#  'añadieron',
#  'incremento',
#  'sustancial',
#  'salario',
#  'mínimo',
#  'línea',
#  'ocurrido',
#  'años',
#  'anteriores',
#  'constituiría',
#  'nuevamente',
#  'obstáculo',
#  'acercarse',
#  'meta',
#  'inflación',
#  'respecto',
#  'panorama',
#  'fiscal',
#  'subrayaron',
#  'mayor',
#  'déficit',
#  'gobierno',
#  'central',
#  'previsto',
#  'genera',
#  'impulso',
#  'macroeconómico',
#  'reflejaría',
#  'mayores',
#  'presiones',
#  'inflacionarias',
#  'incremento',
#  'adicional',
#  'alta',
#  'prima',
#  'riesgo',
#  'país',
#  'señalaron',
#  'favorable',
#  'desempeño',
#  'macroeconómico',
#  'materia',
#  'crecimiento',
#  'empleo',
#  'primera',
#  'mitad',
#  'año',
#  'reduce',
#  'dilemas',
#  'política',
#  'monetaria',
#  'permite',
#  'ésta',
#  'enfoque',
#  'objetivo',
#  'buscar',
#  'convergencia',
#  'inflación',
#  'meta',
#  'mediante',
#  'decisiones',
#  'cautelosas',
#  'tasa',
#  'interés',
#  'grandes',
#  'sacrificios',
#  'económicos',
#  'corto',
#  'plazo',
#  'perspectiva',
#  'lograr',
#  'estabilidad',
#  'precios',
#  'insistieron',
#  'inflación',
#  'constituye',
#  'impuesto',
#  'altamente',
#  'regresivo',
#  'afecta',
#  'desproporcionadamente',
#  'hogares',
#  'condición',
#  'pobreza',
#  'países',
#  'consolidado',
#  'estabilidad',
#  'precios',
#  'tienden',
#  'registrar',
#  'mayores',
#  'tasas',
#  'crecimiento',
#  'buena',
#  'medida',
#  'logran',
#  'mantener',
#  'tasas',
#  'interés',
#  'reales',
#  'bajas',
#  'tiempo',
#  'directores',
#  'votaron',
#  'reducción',
#  'pbs',
#  'sostienen',
#  'tasa',
#  'interés',
#  'real',
#  'política',
#  'monetaria',
#  'descontando',
#  'inflación',
#  'observada',
#  'tasa',
#  'expost',
#  'último',
#  'año',
#  'medio',
#  'enero',
#  'junio',
#  'veces',
#  'superior',
#  'promedio',
#  'enero',
#  'diciembre',
#  'primera',
#  'segunda',
#  'agregan',
#  'actualmente',
#  'ésta',
#  'ubica',
#  'segunda',
#  'alta',
#  'región',
#  'después',
#  'brasil',
#  'basados',
#  'evidencia',
#  'señalan',
#  'postura',
#  'política',
#  'monetaria',
#  'colombia',
#  'altamente',
#  'restrictiva',
#  'segundo',
#  'término',
#  'consideran',
#  'cálculos',
#  'variables',
#  'inobservables',
#  'tales',
#  'tasa',
#  'interés',
#  'neutral',
#  'brecha',
#  'pib',
#  'brecha',
#  'desempleo',
#  'equipo',
#  'técnico',
#  'utiliza',
#  'respaldar',
#  'recomendaciones',
#  'junta',
#  'discutibles',
#  'basadas',
#  'resultados',
#  'modelos',
#  'pueden',
#  'verificarse',
#  'empíricamente',
#  'argumentan',
#  'inflación',
#  'anual',
#  'ubicó',
#  'junio',
#  'reduciéndose',
#  'frente',
#  'registro',
#  'mayo',
#  'sorprendiendo',
#  'baja',
#  'analistas',
#  'mercado',
#  'aunque',
#  'aún',
#  'encuentra',
#  'encima',
#  'rango',
#  'meta',
#  'trayectoria',
#  'descendente',
#  'refuerza',
#  'espacio',
#  'continuar',
#  'reducción',
#  'tasas',
#  'equipo',
#  'técnico',
#  'dirección',
#  'general',
#  'política',
#  'macroeconómica',
#  'ministerio',
#  'hacienda',
#  'dgpm',
#  'proyecta',
#  'última',
#  'actualización',
#  'supuestos',
#  'macroeconómicos',
#  'inflación',
#  'sitúe',
#  'cierre',
#  'expectativas',
#  'inflación',
#  'cierre',
#  'ubican',
#  'julio',
#  'disminuyendo',
#  'pbs',
#  'frente',
#  'esperado',
#  'mes',
#  'pasado',
#  'además',
#  'expectativas',
#  'meses',
#  'mantienen',
#  'ancladas',
#  'rango',
#  'meta',
#  'banco',
#  'república',
#  'ubicándose',
#  'respectivamente',
#  'sugiere',
#  'espacio',
#  'mantener',
#  'senda',
#  'recortes',
#  'tasa',
#  'interés',
#  'tasa',
#  'interés',
#  'real',
#  'ubicaría',
#  'julio',
#  'pps',
#  'encima',
#  'nivel',
#  'neutral',
#  'estimado',
#  'banco',
#  'república',
#  'dado',
#  'espera',
#  'inflación',
#  'mantenga',
#  'senda',
#  'decreciente',
#  'resto',
#  'año',
#  'brecha',
#  'producto',
#  'ubique',
#  'terreno',
#  'negativo',
#  'considera',
#  'apropiado',
#  'continuar',
#  'implementando',
#  'reducciones',
#  'tasa',
#  'interés',
#  'próximas',
#  'reuniones',
#  'jdbr',
#  'insisten',
#  'tasas',
#  'interés',
#  'reales',
#  'altas',
#  'actualmente',
#  'observan',
#  'colombia',
#  'afectan',
#  'posibilidades',
#  'crecimiento',
#  'económico',
#  'particular',
#  'dinamismo',
#  'sector',
#  'manufacturero',
#  'requiere',
#  'incentivos',
#  'mayores',
#  'considera',
#  'continuar',
#  'trayectoria',
#  'reducciones',
#  'tasa',
#  'interés',
#  'favorecería',
#  'impulso',
#  'sector',
#  'industrial',
#  'crecimiento',
#  'económico',
#  'agregaron',
#  'reducción',
#  'tasas',
#  'interés',
#  'ofrecería',
#  'estímulo',
#  'importante',
#  'microcrédito',
#  'economía',
#  'popular',
#  'igual',
#  'forma',
#  'sustentan',
#  'incrementos',
#  'salario',
#  'mínimo',
#  'real',
#  'últimos',
#  'tres',
#  'años',
#  'efectos',
#  'inflacionarios',
#  'insinuados',
#  'lado',
#  'contribuido',
#  'reducción',
#  'indicadores',
#  'pobreza',
#  'evidencia',
#  'tasa',
#  'desempleo',
#  'decreciente',
#  'reducción',
#  'pobreza',
#  'monetaria',
#  'atender',
#  'desequilibrios',
#  'fiscales',
#  'prioritario',
#  'garantizar',
#  'mayor',
#  'crecimiento',
#  'economía',
#  'ley',
#  'financiamiento',
#  'permita',
#  'sostenibilidad',
#  'fiscal',
#  'mediano',
#  'plazo',
#  'director',
#  'votó',
#  'recorte',
#  'pbs',
#  'considera',
#  'cumplir',
#  'mandato',
#  'constitucional',
#  'controlar',
#  'inflación',
#  'realiza',
#  'contexto',
#  'cumplir',
#  'objetivo',
#  'principal',
#  'política',
#  'económica',
#  'mantener',
#  'crecimiento',
#  'sostenido',
#  'aumentar',
#  'empleo',
#  'especialmente',
#  'país',
#  'desigual',
#  'colombia',
#  'concuerda',
#  'si',
#  'bien',
#  'coyuntura',
#  'fiscal',
#  'compleja',
#  'distancia',
#  'expectativas',
#  'excesivamente',
#  'negativas',
#  'posible',
#  'deterioro',
#  'fiscal',
#  'valora',
#  'transparencia',
#  'gobierno',
#  'campo',
#  'subraya',
#  'pesar',
#  'activación',
#  'cláusula',
#  'escape',
#  'regla',
#  'fiscal',
#  'reducción',
#  'calificación',
#  'crediticia',
#  'prima',
#  'riesgo',
#  'venido',
#  'disminuyendo',
#  'últimas',
#  'semanas',
#  'corrigiendo',
#  'desviaciones',
#  'previas',
#  'muestra',
#  'reciente',
#  'descenso',
#  'cds',
#  'adicionalmente',
#  'observa',
#  'tasa',
#  'cambio',
#  'permanecido',
#  'sendas',
#  'debajo',
#  'pesos',
#  'converge',
#  'variaciones',
#  'países',
#  'región',
#  'dando',
#  'ello',
#  'señales',
#  'estabilidad',
#  'finalmente',
#  'advierte',
#  'si',
#  'bien',
#  'variables',
#  'macroeconómicas',
#  'continúan',
#  'senda',
#  'positiva',
#  'inversión',
#  'privada',
#  'disminuye',
#  'sectores',
#  'tradicionales',
#  'razón',
#  'importante',
#  'dar',
#  'señales',
#  'permitan',
#  'dar',
#  'confianza',
#  'inversión',
#  'tasa',
#  'interés',
#  'política',
#  'cumple',
#  'función',
#  'esencial']

# %%
print("--- Antes del preprocesamiento ---")
print(texto_banco_republica[:175] + "...")
print("\n--- Después del preprocesamiento (primeros 20 tokens) ---")
print(tokens_filtrados[:12])
# Out:
# --- Antes del preprocesamiento ---
#
# Entre mayo y junio la inflación anual se redujo de 5,1% a 4,8%. Esta disminución fue impulsada por la moderación de la inflación de las canastas de alimentos y de regulados. ...
#
# --- Después del preprocesamiento (primeros 20 tokens) ---
# ['mayo', 'junio', 'inflación', 'anual', 'redujo', 'disminución', 'impulsada', 'moderación', 'inflación', 'canastas', 'alimentos', 'regulados']

# %% [markdown]
# ## Análisis de Frecuencia
#
# Una vez que tenemos los tokens limpios, el análisis más directo es contar cuáles son los más frecuentes. Esto nos da una idea clara de los temas centrales del documento.

# %%
# Usamos FreqDist de NLTK para contar la frecuencia de cada token
freq = nltk.FreqDist(tokens_filtrados)

print("Las 10 palabras más frecuentes:")
display(freq.most_common(10))
# Out:
# Las 10 palabras más frecuentes:
# [('inflación', 23),
#  ('tasa', 16),
#  ('interés', 14),
#  ('reducción', 10),
#  ('política', 10),
#  ('crecimiento', 8),
#  ('fiscal', 7),
#  ('anual', 6),
#  ('expectativas', 6),
#  ('meta', 6)]

# %% [markdown]
# Ahora, visualicemos esto con una nube de palabras.

# %% [markdown]
# ## Nube de palabras (Word Cloud)
#
# Es una **herramienta de visualización de texto** que representa las palabras más frecuentes en un conjunto de datos textuales, donde el tamaño de cada palabra refleja su frecuencia o relevancia. Es muy útil como primer paso exploratorio y como recurso visual y comunicativo
#
# Sirve para:
#
# - Exploración rápida de texto: Permite tener una visión general de los temas más recurrentes en un documento, corpus de textos, redes sociales, encuestas abiertas, reseñas, etc.
#
# - Identificación de patrones y temas clave: Destaca las palabras que más aparecen, ayudando a detectar tendencias, intereses o preocupaciones en un grupo de personas.
#
# - Comunicación visual: Resume información textual de manera atractiva y comprensible para públicos no técnicos, útil en presentaciones o reportes.
#
# - Detección preliminar de sesgos o errores: Si aparecen muchas palabras irrelevantes (ej. “el”, “la”, “que”), puede evidenciar la necesidad de limpieza de datos (stopwords, lematización).

# %%
texto_para_nube = " ".join(tokens_filtrados)
texto_para_nube
# Out:
# 'mayo junio inflación anual redujo disminución impulsada moderación inflación canastas alimentos regulados caso alimentos inflación cayó debido principalmente reducción inflación perecederos cuanto regulados inflación redujo jalonada menor inflación servicios públicos especialmente energía eléctrica inflación básica alimentos regulados estabilizó interrumpiendo tendencia descendente resultado alzas bienes servicios diversos expectativas inflación mantuvieron encima meta caso analistas según encuestas julio éstas sitúan mediana finales respectivamente expectativas obtenidas mercados deuda pública muestran comportamientos mixtos actividad económica continúa dinamismo observado primer trimestre alcanzó crecimiento anual efecto índice seguimiento economía ise presentó mayo variación anual liderado actividades terciarias indicadores ventas menor producción manufacturera demanda energía mostraron resultados positivos base equipo técnico estima segundo trimestre actividad económica crecería ritmo anual jalonado demanda interna expandiría condiciones financiamiento externo país mantienen restrictivas entorno elevada incertidumbre mundial conflictos varias regiones mundo tensiones comerciales globales obstante moderado lenta normalización esperada política monetaria unidos respecto dos últimas recientes negociaciones comerciales unidos economías china reino unido unión europea acordado aranceles bajos inicialmente anunciados parte unidos reserva federal fed mantuvo inalterada tasa interés política monetaria sesión julio directores junta coincidieron destacar buen desempeño economía colombiana venido mostrando corrido año caracterizado actividad económica dinámica reducción tasa desempleo contexto crédito comienza mostrar tasas crecimiento reales positivas resaltaron fortalecimiento demanda interna impulsada principalmente consumo privado reconocieron ritmo descenso inflación primera mitad sido lento esperado entorno choques origen externo tornado condiciones financieras internacionales especialmente restrictivas señalaron persistente desajuste fiscal crea retos importantes país condiciones cuatro miembros junta inclinaron mantener inalterada tasa interés política dos votaron reducción pbs recorte pbs miembros grupo mayoritario señalaron reducción inflación anual observada junio perspectivas trayectoria próximos meses crean condiciones propicias proceder recorte tasa interés política advierten trató resultado origen puntual asegura convergencia inflación hacia meta horizonte prudente respecto anotaron inflación básica alimentos regulados mantuvo inalterada junio expectativas inflación fines medidas julio redujeron respecto existían mayo equipo técnico proyecta inflación total básica respectivamente obstante directores resaltaron vislumbran riesgos inflacionarios corto plazo llegarse presentar faltantes financiamiento déficit fiscal cuenta corriente balanza pagos presionen alza tasa cambio añadieron incremento sustancial salario mínimo línea ocurrido años anteriores constituiría nuevamente obstáculo acercarse meta inflación respecto panorama fiscal subrayaron mayor déficit gobierno central previsto genera impulso macroeconómico reflejaría mayores presiones inflacionarias incremento adicional alta prima riesgo país señalaron favorable desempeño macroeconómico materia crecimiento empleo primera mitad año reduce dilemas política monetaria permite ésta enfoque objetivo buscar convergencia inflación meta mediante decisiones cautelosas tasa interés grandes sacrificios económicos corto plazo perspectiva lograr estabilidad precios insistieron inflación constituye impuesto altamente regresivo afecta desproporcionadamente hogares condición pobreza países consolidado estabilidad precios tienden registrar mayores tasas crecimiento buena medida logran mantener tasas interés reales bajas tiempo directores votaron reducción pbs sostienen tasa interés real política monetaria descontando inflación observada tasa expost último año medio enero junio veces  ...

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(texto_para_nube)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Términos Clave en el Comunicado del Banco de la República', fontsize=16)
plt.show()

# %% [markdown]
# **Interpretación Económica:** La nube de palabras resalta instantáneamente los conceptos centrales, donde 'inflación', 'tasa', 'interés', 'crecimiento', 'reducción', son visiblemente los más importantes. Esto confirma, sin necesidad de leer el documento completo, que el comunicado trata sobre el trade-off entre controlar la inflación mediante la tasa de interés y su posible efecto en el crecimiento económico. Es una herramienta poderosa para el análisis rápido de sentimiento y enfoque de política.

# %% [markdown]
# ## Ejercicio
#
# Ahora vamos a modificar la lista de `stop_words` para incluir otras palabras que no agreguen mucho significado, y volvemos a generar la nube de palabras. ¿Qué términos ganan importancia una vez que eliminamos las otras palabras que hacían ruido?

# %%
# 1. Creamos una nueva lista de stop words extendida
stop_words_personalizada = set(stopwords.words('spanish'))
stop_words_personalizada.update(['junta', 'directiva', 'sesión', 'hoy', 'decidió', 'equipo', 'técnico', 'pbs',
                                 'respectivamente', 'resultado', 'considera', 'unido', 'anual', 'año',
                                 'especialmente', 'directores', 'tasa', 'ésta'])

# %%
# 2. Re-filtramos los tokens originales
tokens_originales = word_tokenize(re.sub(r'[^a-záéíóúñ\s]', '', texto_banco_republica.lower()), 'spanish')
tokens_filtrados_v2 = [palabra for palabra in tokens_originales if palabra not in stop_words_personalizada]

# %%
# 3. Generamos la nueva nube de palabras
texto_para_nube_v2 = " ".join(tokens_filtrados_v2)
wordcloud_v2 = WordCloud(width=800, height=400, background_color='black', colormap='plasma').generate(texto_para_nube_v2)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud_v2, interpolation='bilinear')
plt.axis("off")
plt.title('Términos Clave en el Comunicado del Banco de la República')
plt.show()

# %% [markdown]
# Al eliminar los términos institucionales, palabras como 'inflación', 'interés', 'crecimiento' y 'reducción' se vuelven más visibles. Esto nos ayuda a enfocarnos aún más en los conceptos claves del comunicado.

# %% [markdown]
# ## Análisis de sentimientos

# %% [markdown]
# Vamos a trabajar con un conjunto de datos de reseñas en español.
#
# Link: https://github.com/AlessandroGianfelici/spanish_reviews_dataset
#
# Este conjunto de datos se ha recopilado de internet mediante técnicas de web scraping.
#
# Para cada observación, el conjunto de datos contiene el nombre de la empresa (codificado por razones de privacidad), el título de la reseña, el texto de la reseña y el número de estrellas (de 1 a 5).
#
# El dataset se encuentra en el repositorio del curso, carpeta 'datasets', archivo 'reviews_data.txt'

# %% [markdown]
# ### Cargar el dataset

# %%
from google.colab import drive, files
drive.mount('/content/drive')

# %%
path = 'C:\\Users\\Ferney Reina\\Documents\\Python\\IA_Economia\\2025-segundo-semestre-ia-economia\\datasets'

# %%
# Para establecer el directorio de los archivos
os.chdir(path)

# %%
df = pd.read_csv('reviews_data.txt')
df
# Out:
#               company_name                                       review_title  \
# 0     -8121737614821815175              Reservamos en el camping delfin verde
# 1     -8121737614821815175                  Resnervamos en el mes de mayo un…
# 2     -8121737614821815175  Mas barato pero sucio y sin atención en castel...
# 3     -8121737614821815175                                    Flipando sigo!!
# 4     -8121737614821815175                            Allcamps unos timadores
# ...                    ...                                                ...
# 67139 -4912670274258787853               Estafadores.Hice un pedido hace dos…
# 67140 -4912670274258787853                            El pedido NO ha llegado
# 67141 -4912670274258787853                            Mucho retraso en envíos
# 67142 -4912670274258787853                        Horrible. Rozando la estafa
# 67143 -2107079195336204062                                              Happy
#
#                                              review_text  review_stars
# 0      Reservamos en el camping delfin verde, el bung...             1
# 1      Reservamos en el mes de mayo un bungalow de 8 ...             1
# 2      Hemos estado en un bungalow en el camping inte...             1
# 3      Haber, me cojo un camping, con el servicio est...             1
# 4      Allcamps unos timadores. No hagáis reservas a ...             1
# ...                                                  ...           ...
# 67139  Estafadores.Hice un pedido hace dos meses y ni...             1
# 67140  El pedido NO ha llegado. Tendía que tardar ent...             1
# 67141  Aún no he recibido el producto y ya van diez d...             2
# 67142  no hay palabras para describir lo malo de esta...             1
# 67143  Me gusto mucho las targetas. Un trabajo muy bi...             5
#
# [67144 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 67144 entries, 0 to 67143
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   company_name  67144 non-null  int64
#  1   review_title  67144 non-null  object
#  2   review_text   67144 non-null  object
#  3   review_stars  67144 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 2.0+ MB

# %% [markdown]
# ### Vamos a analizar las reseñas positivas de una sola compañía

# %%
# Vamos a seleccionar una sola compañía y vamos a analizarsus reseñas
df_pos = df[(df['company_name']==-8121737614821815175) & (df['review_stars']>=4)]
df_pos
# Out:
#               company_name                              review_title  \
# 10    -8121737614821815175  Vamos el 24 de junio-Necesito respuestas
# 13    -8121737614821815175   El año pasado estuvimos en un bungalow…
# 15    -8121737614821815175       Por ahora todo muy correcto cuando…
# 17    -8121737614821815175          Perfecto muy rapido y muy fácil.
# 1948  -8121737614821815175                             Todo perfecto
# ...                    ...                                       ...
# 60027 -8121737614821815175              Fue una experiencia positiva
# 60028 -8121737614821815175                             Todo correcto
# 60029 -8121737614821815175                       Todo fue muy bien!!
# 60030 -8121737614821815175    Todo perfecto y disfrutamos mucho del…
# 60031 -8121737614821815175                Muy bien las instalaciones
#
#                                              review_text  review_stars
# 10     Vamos el 24 de junio, no consigo que me respon...             5
# 13     El año pasado estuvimos en un bungalow de su e...             5
# 15     Por ahora todo muy correcto cuando utilice la ...             4
# 17                      Perfecto muy rapido y muy fácil.             5
# 1948                                       Todo perfecto             5
# ...                                                  ...           ...
# 60027  Fue una experiencia positiva, nos cambiaron un...             5
# 60028           Todo correcto. Nada especial a destacar.             4
# 60029          Todo fue muy bien!!\r\nRepetimos otro año             4
# 60030      Todo perfecto y disfrutamos mucho del camping             5
# 60031                         Muy bien las instalaciones             4
#
# [71 rows x 4 columns]

# %%
df_pos['review_stars'].value_counts(normalize=True)
# Out:
# review_stars
# 5   0.68
# 4   0.32
# Name: proportion, dtype: float64

# %%
# Concatenar todas las filas de la columna en un solo texto
texto_pos = " ".join(df_pos["review_text"])
texto_pos
# Out:
# 'Vamos el 24 de junio, no consigo que me respondan los mails.\r\n¿a que hora podemos llegar como muy tarde?\r\n¿Las piscinas estan abiertas?¿Tenemos 2 niños, hay animación?\r\n***** \r\nBuenas, tengo que admitir que tras esta opinión ... nos respondieron! Y todo fue perfecto! Si vais dese El  Estado Españos o desde el País Vasco, no nos pidieron pruebas de PCR en ningún sitio. \r\nEl camping muy recomendable, estuvimos muy agusto y la zona también! Buen viaje y disfrutad! Que son dos días!!!!! (Estoy pensando cambiar nuestro destino de Peñiscola de Junio por este camping y esta zona!!) El año pasado estuvimos en un bungalow de su empresa y nos gustó mucho, por eso este año hemos reservado el mismo tipo de bungalow.\r\nNos gustó mucho el bungalow y la situación de éste. Por ahora todo muy correcto cuando utilice la reserva para junio y no surge ningún problema le pondré 5 estrellas Perfecto muy rapido y muy fácil. Todo perfecto todo muy bien organizado, claro y con una perfectea atención al cliente. El espacio estaba muy limpio, equipado con todo lo necesario y la persona que nos atendió durante la estancia, Eileen, es una gran anfitriona. Estamos muy contentos de haber escogida esta opción para nuestras vacaciones. Unas vacaciones fantásticas en un lugar increíble. \r\nLos bungalows perfectos y limpios. \r\nNos atendieron muy bien en todo momento. Todo genial gracias Estaba todo perfecto, las habitaciones eran cómodas, había aire acondicionado, una terraza para poder comer y desayunar. El cmaping fue muy divertido para ir en familia y niños pequeños.\r\nEl precio muy económico y todo perfecto. Nosotros estuvimos 3 noches. El camping estaba muy bien. Muchas zonas verdes y parques. La piscina está increíble, con toboganes muy divertidos y una piscina tipo playa para los peques muy chula.\r\n El bungalow era muy minimalista pero tenías todo lo que necesitabas. Fuimos dos parejas y estuvimos muy bien. La señora que gestionaba los bungalows de allcamps en el camping fue muy amable. Sólo habla inglés pero se preocupa de que la entiendas. \r\nEstaba todo muy limpio. Y ahora con el COVID-19 se agradece.\r\nAl finalizar la estancia te daban dos opciones: podías desinfectar tu mismo el bungalow (ellos te daban los productos) o pagabas 40€ y lo hacían ellos.\r\nAl ser un bungalow pequeño decidimos desinfectarlo nosotros.\r\n\r\nFue una experiencia corta pero muy satisfactoria.\r\nSin duda volveremos! La casa estaba no tan limpia como queria pero bueno. \r\nIdeal para descanso familiar. Hemos pasado unas vacaciones estupendas con allcamps, en un entorno maravilloso, repetiremos. Estuvimos alojados en el Càmping Castell Montgrí y nos trataron super bien, la pareja que nos atendio fue super amable y siempre estuvo pendiente de que todo fuera bien Todo limpio y puntuales.\r\nRepetiremos seguro Todo perfecto. Tanto la llegada como la salida fue muy fácil con Allcamps. Se adaptaron a nuestros horarios y fueron muy amables.\r\nEl precio bastante menor que en otras páginas. Todo genial, estuvimos en septiembre en Cypsela Resort, y la verdad que muy bien!!! Estuvimos en agosto y super bien, cuando llegamos nos atendieron enseguida y nos tocó una casita en la esquina con lo que aparcar el coche fue mucho más fácil, la lástima es que en la zona de las casitas sólo había una chica hablando español, el resto otros idiomas. El personal es muy atento y amable. Había mucha gente pero aún así, todo correcto con las precauciones adecuadas. El personal del restaurante estaban constantemente desinfectando las mesas y sillas ocupadas para que otra familia las pudiera ocupar. En resumen, estamos muy contentos y lo recomendamos. TODO GENIAL! Buen precio y buenos bungalows, el camping en general esta muy bien. Tour operador de campings que ofrece precios muy competitivos. Los bungalows son como muestran las imágenes y tienes contacto con ellos durante la estancia. Muy recomendables. El camping y todo el servicio estuvo muy bien \r\nTodo estaba perfecto  y los c ...

# %%
# 1. Normalización: Convertir todo a minúsculas para que 'Inflación' e 'inflación' se traten como la misma palabra.
texto_limpio = texto_pos.lower()

# 2. Limpieza de caracteres no alfabéticos: Usamos expresiones regulares para quitar puntuación y números.
texto_limpio = re.sub(r'[^a-záéíóúñ\s]', '', texto_limpio)

# 3. Tokenización: Dividir el texto en una lista de palabras individuales (tokens).
tokens = word_tokenize(texto_limpio, 'spanish')

# 4. Eliminación de Stop Words: Quitar palabras comunes en español que no aportan significado económico.
stop_words_es = set(stopwords.words('spanish'))

tokens_filtrados = [palabra for palabra in tokens if palabra not in stop_words_es]

# %%
# Usamos FreqDist de NLTK para contar la frecuencia de cada token
freq = nltk.FreqDist(tokens_filtrados)

print("Las 10 palabras más frecuentes:")
display(freq.most_common(10))
# Out:
# Las 10 palabras más frecuentes:
# [('bien', 21),
#  ('perfecto', 19),
#  ('camping', 15),
#  ('bungalow', 10),
#  ('buen', 8),
#  ('estancia', 8),
#  ('genial', 8),
#  ('servicio', 7),
#  ('correcto', 6),
#  ('limpio', 6)]

# %%
# 1. Creamos una nueva lista de stop words extendida
stop_words_personalizada = set(stopwords.words('spanish'))
stop_words_personalizada.update(['camping', 'bungalow', 'bungalows', 'allcamps'])

# 2. Re-filtramos los tokens originales
tokens_originales = word_tokenize(re.sub(r'[^a-záéíóúñ\s]', '', texto_pos.lower()), 'spanish')
tokens_filtrados_v2 = [palabra for palabra in tokens_originales if palabra not in stop_words_personalizada]

# %%
# Ahora, visualicemos esto con una nube de palabras.
# La nube de palabras es excelente para presentaciones, ya que resume el contenido de forma visual e impactante.
texto_para_nube = " ".join(tokens_filtrados_v2)

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(texto_para_nube)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Reseñas positivas', fontsize=16)
plt.show()

# %% [markdown]
# ### Ahora, vamos a analizar las reseñas negativas

# %%
df_neg = df[(df['company_name']==-8121737614821815175) & (df['review_stars']<=2)]
df_neg
# Out:
#               company_name                                       review_title  \
# 0     -8121737614821815175              Reservamos en el camping delfin verde
# 1     -8121737614821815175                  Resnervamos en el mes de mayo un…
# 2     -8121737614821815175  Mas barato pero sucio y sin atención en castel...
# 3     -8121737614821815175                                    Flipando sigo!!
# 4     -8121737614821815175                            Allcamps unos timadores
# 5     -8121737614821815175   Bungalow en camping el delfín Verde con allcamps
# 6     -8121737614821815175                   Son unos estafadores y timadores
# 7     -8121737614821815175                                             Penoso
# 9     -8121737614821815175                                        Descontenta
# 11    -8121737614821815175                             Garantía covid un timo
# 12    -8121737614821815175                  Un trato lamentable por pandemia…
# 14    -8121737614821815175                                Publicidad engañosa
# 18    -8121737614821815175              Preferiria tener contacto telefonico…
# 29471 -8121737614821815175                Ni se te ocurra contratar con ellos
# 29483 -8121737614821815175                     Una atención al cliente pésima
# 35573 -8121737614821815175                                              Fatal
# 35580 -8121737614821815175           Toda la organizacion muy mala estoy muy…
# 46754 -8121737614821815175              No hubo comunicación de intermedarios
# 46755 -8121737614821815175                             No reservéis con ellos
# 60019 -8121737614821815175                       Horrible, nada recomendable.
#
#                                              review_text  review_stars
# 0      Reservamos en el camping delfin verde, el bung...             1
# 1      Reservamos en el mes de mayo un bungalow de 8 ...             1
# 2      Hemos estado en un bungalow en el camping inte...             1
# 3      Haber, me cojo un camping, con el servicio est...             1
# 4      Allcamps unos timadores. No hagáis reservas a ...             1
# 5      Hemos reservado bungalow en camping el delfín ...             1
# 6      Son unos estafadores y timadores Te dejan tira...             1
# 7      Hemos reservado muchas veces. Siempre nos ha i...             1
# 9      Hemos estado en el camping Delfín Verde, a tra...             1
# 11     Trato nefasto. Las condiciones de mi reserva c...             1
# 12     Un trato lamentable por pandemia tuvimos que s...             1
# 14     Recientemente he reservado y para mí sorpresa ...             1
# 18     Preferiria tener contacto telefonico que por i...             1
# 29471  Ni se te ocurra contratar con ellos. El año pa...             1
# 29483  Una atención al cliente pésima. El personal de...             1
# 35573                      Fatal, tres noches sin dormir             1
# 35580  Toda la organizacion muy mala estoy muy enfada...             1
# 46754              No hubo comunicación de intermedarios             2
# 46755  No reservéis con ellos. No son nada comprensiv...             1
# 60019  Reservamos a través de allcamps y el resultado...             1

# %%
df_neg['review_stars'].value_counts(normalize=True)
# Out:
# review_stars
# 1   0.95
# 2   0.05
# Name: proportion, dtype: float64

# %%
# Concatenar todas las filas de la columna en un solo texto
texto_neg = " ".join(df_neg["review_text"])
texto_neg
# Out:
# 'Reservamos en el camping delfin verde, el bungalow sucio, el somier de matrimonio roto, no tenía llaves el bungalow por lo que todo se quedaba abierto, nos llovió 2 días y tenía goteras, y para colmo  se embozó el water y la pica el mismo día de entrada y nos lo solucionaron a los 3 días, decidí irme antes de acabar la estacia, espero que me den una solución Reservamos en el mes de mayo un bungalow de 8 personas,6 dias para los dias del 30 d agosto al 5 septiembre.Al llegar nos sentimos estafados sin poder conectar con nadie.sin oficinas y sin poder contactar por teléfono.nos cobraron 846 euros por un supuesto bungalow comfort.no tiene ni tv ni utensilios para 8 personas ni camas para 8 personas.visitamos un bungalow d unos amigos del camping y era nuevo y comfortable.y habian pagado la mitad.nadie nos ayuda ni responde.Es una gran estafa. Hemos estado en un bungalow en el camping internacional Calonge. El camping bien pero el servicio de Allcamp muy deficients. El bungalow muy sucio, no lo repasan cuando marchan otros clientes. Pocas luces y la mitad fundidas. La recepción para entregar las llaves de Allcamps  (o eurocamps) olo abre de 3-6 h, habia un telefono para llamar, era un numero creo que de Alemania y no hablaban castellano.  La persona que nos dió las llaves tampoco hablaba castellano. En la web pone un tlfo de España para contactar y aclarar dudas que no está operativo. En definitiva, si la diferencia de precio no es muy grande mejor contratar diréctamente con el camping, que ellos si te resuelven cualquier duda o incidente, si no a cruzar los dedos y llevar productos de limpieza Haber, me cojo un camping, con el servicio este del cov que dan, porque tal cual está todo.. me pongo en contacto con ellos, y me dicen que sin problema, que la pasta no la dan, pero que mover fechas son problemas.. ok pos lo cojo.. ayer di positivo.. pos ahora resulta de que no me mueven las fechas.. la chica del teléfono.. bueno mejor ni comentar.. xk después de que me están diciendo que he perdido 800 euros me chille ella a mí.. me parece un poco subrealista en la ocu estáis panda de desgraciados Allcamps unos timadores. No hagáis reservas a través de esta página. No es cierto lo que es a lo que ofrecen. Hemos reservado bungalow en camping el delfín Verde con Allcamps. Es la primera vez. El bungalow muy sucio. Se notaba que no realizan limpieza cada vez que se va un cliente. La cocina daba bastante asco. Las cortinas y el sofá con manchas. La luz exterior no funcionaba, avisamos y nos fuimos sin que la hubiesen arreglado. Persona responsable sólo habla inglés. El camping muy bien. Piscinas y servicios muy bien. Lo único que casi nadie llevaba mascarilla, sobretodo extranjeros. \r\nEl precio más económico del bungalow no justifica la falta de limpieza. Son unos estafadores y timadores Te dejan tirado sin avisarte. Además no atienden el teléfono con la excusa del Covid. 0,000% recomendable. Hemos reservado muchas veces. Siempre nos ha ido bien, pero justamente hoy hemos reservado un módulo confort con tres habitaciones el cual cuando hemos llegado estaba a medio limpiar con toda la basura de los otros clientes tirados en la misma puerta después la nevera rota el calentador no funciona faltan cortinas faltan almohadas y hasta el cubo de la basura y cuando nos hemos quejado nos han dicho que ahora venía la reparárnoslo pues bien después de estar una hora esperando a que vinieran hemos ido habían cerrado y se habían ido a su casa teniendo dos niños pequeños que tienen que cenar y se tienen que bañar así que como comprenderéis es una vergüenza y los empleados unos maleducados además de unos mentirosos Hemos estado en el camping Delfín Verde, a través de allcamps, las tiendas que tienen Glam Lodge, estaban  las camas muy deterioradas. daban asco y muy sucio todo. La persona que te atiende es un hombre Holandés que no sabe hablar nada Español. Trato nefasto. Las condiciones de mi reserva cambiaron debido al covid, y a pesar de alardear en su pá ...

# %%
# 1. Normalización: Convertir todo a minúsculas para que 'Inflación' e 'inflación' se traten como la misma palabra.
texto_limpio = texto_neg.lower()

# 2. Limpieza de caracteres no alfabéticos: Usamos expresiones regulares para quitar puntuación y números.
texto_limpio = re.sub(r'[^a-záéíóúñ\s]', '', texto_limpio)

# 3. Tokenización: Dividir el texto en una lista de palabras individuales (tokens).
tokens = word_tokenize(texto_limpio, 'spanish')

# 4. Eliminación de Stop Words: Quitar palabras comunes en español que no aportan significado económico.
stop_words_es = set(stopwords.words('spanish'))

tokens_filtrados = [palabra for palabra in tokens if palabra not in stop_words_es]

# %%
# Usamos FreqDist de NLTK para contar la frecuencia de cada token
freq = nltk.FreqDist(tokens_filtrados)

print("Las 10 palabras más frecuentes:")
display(freq.most_common(10))
# Out:
# Las 10 palabras más frecuentes:
# [('camping', 12),
#  ('bungalow', 12),
#  ('euros', 6),
#  ('si', 6),
#  ('sucio', 5),
#  ('bien', 5),
#  ('allcamps', 5),
#  ('reserva', 5),
#  ('dias', 4),
#  ('mejor', 4)]

# %%
# 1. Creamos una nueva lista de stop words extendida
stop_words_personalizada = set(stopwords.words('spanish'))
stop_words_personalizada.update(['camping', 'bungalow', 'bungalows', 'si', 'allcamps'])

# 2. Re-filtramos los tokens originales
tokens_originales = word_tokenize(re.sub(r'[^a-záéíóúñ\s]', '', texto_neg.lower()), 'spanish')
tokens_filtrados_v2 = [palabra for palabra in tokens_originales if palabra not in stop_words_personalizada]

# %%
# Ahora, visualicemos esto con una nube de palabras.
# La nube de palabras es excelente para presentaciones, ya que resume el contenido de forma visual e impactante.
texto_para_nube = " ".join(tokens_filtrados_v2)

# %%
wordcloud = WordCloud(width=800, height=400, background_color='white', colormap='viridis').generate(texto_para_nube)

plt.figure(figsize=(12, 6))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.title('Reseñas negativas', fontsize=16)
plt.show()

# %% [markdown]
# ### Análisis de sentimientos con un modelo preentrenado de redes neuronales

# %% [markdown]
# **Hugging Face** es el ecosistema más usado actualmente para acceder, usar y compartir **modelos de IA preentrenados**. Lo hace tan sencillo que con unas pocas líneas de código ya puedes aplicar análisis de sentimientos, traducción, chatbots, clasificación de texto y mucho más.

# %% [markdown]
# Un modelo preentrenado de HuggingFace para análisis de sentimientos en español es una red neuronal de lenguaje natural (NLP) que ya fue entrenada previamente con millones de textos en español. Por eso, en lugar de partir de cero, podemos aprovechar su conocimiento del idioma y de cómo se expresan emociones.
#
# El entrenamiento se hace con datasets grandes de reseñas, tweets o comentarios que ya tienen una etiqueta de sentimiento (positivo, negativo, neutral).
#
# Lo interesante es que el modelo no solo busca palabras individuales (como "bueno", "excelente",...), sino que entiende contexto, negaciones, sarcasmo y combinaciones de palabras.
#
# En la práctica, lo usamos cargándolo con transformers (HuggingFace) y con una sola línea ya puede clasificar cada comentario en positivo/negativo/neutral sin necesidad de entrenar nada adicional.

# %%
# %pip install transformers

from transformers import pipeline
# Out:
# Requirement already satisfied: transformers in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (4.56.2)
# Requirement already satisfied: filelock in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (3.19.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.35.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\ferney reina\appdata\roaming\python\python313\site-packages (from transformers) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2025.9.18)
# Requirement already satisfied: requests in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (0.6.2)
# Requirement already satisfied: tqdm>=4.27 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from transformers) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (2025.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from huggingface-hub<1.0,>=0.34.0->transformers) (4.15.0)
# Requirement already satisfied: colorama in c:\users\ferney reina\appdata\roaming\python\python313\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from requests->transformers) (2025.8.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install torch
import torch

# Cargar un modelo multilingüe de sentimientos
analisis = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")
# Out:
# Requirement already satisfied: torch in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (2.8.0)
# Requirement already satisfied: filelock in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.19.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (4.15.0)
# Requirement already satisfied: sympy>=1.13.3 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (2025.9.0)
# Requirement already satisfied: setuptools in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from torch) (80.9.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ferney reina\appdata\local\programs\python\python313\lib\site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[48], line 5
#       2 import torch
#       4 # Cargar un modelo multilingüe de sentimientos
# ----> 5 analisis = pipeline("sentiment-analysis", model="nlptown/bert-base-multilingual-uncased-sentiment")
#
# File c:\Users\Ferney Reina\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\pipelines\__init__.py:1018, in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, processor, framework, revision, use_fast, token, device, device_map, dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#    1013         raise ValueError(
#    1014             'You cannot use both `pipeline(... dtype=..., model_kwargs={"dtype":...})` as those'
#    1015             " arguments might conflict, use only one.)"
#    1016         )
#    1017 if dtype is not None:
# -> 1018     if isinstance(dtype, str) and hasattr(torch, dtype):
#    1019         dtype = getattr(torch, dtype)
#    1020     model_kwargs["dtype"] = dtype
#
# NameError: name 'torch' is not defined

# %%
df_empresa = df[(df['company_name']==-8121737614821815175)]

# %%
# Aplicar a cada comentario
df_empresa["puntaje"] = df_empresa["review_text"].apply(lambda x: analisis(x)[0]["label"])

# %%
df_empresa.head()

# %% [markdown]
# Este modelo devuelve etiquetas tipo “1 star” a “5 stars”, que puedes mapear a:
#
# 1–2 estrellas → negativo
#
# 3 estrellas → neutral
#
# 4–5 estrellas → positivo

# %%
df_empresa["puntaje"].value_counts()

# %%
def clasificar(puntaje):
    if puntaje == '5 stars' or puntaje == '4 stars':
        return "positivo"
    elif puntaje == '3 stars':
        return "neutral"
    else:
        return "negativo"

df_empresa["sentimiento"] = df_empresa["puntaje"].apply(clasificar)

# %%
sns.countplot(x="sentimiento", data=df_empresa)
plt.title("Distribución del sentimiento de los comentarios")
plt.show()
